# %% [markdown]
# 1. # Clustering Economic Regimes in Iran (1960–2024)
#
# This notebook applies unsupervised learning techniques to identify distinct economic regimes based on macroeconomic indicators.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)
